# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# Import NumPy and Pandas
import numpy as np
import pandas as pd

# Auto reloads notebook when changes are made
# %reload_ext autoreload
# %autoreload 2

# %%
data = pd.read_csv('reps.csv')
X=data['Food']
Y=data['Reps']
plt.scatter(X,Y)
plt.xlabel = "Food"
plt.ylabel = "Reps"
plt.show()
